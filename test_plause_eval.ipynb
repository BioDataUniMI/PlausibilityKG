# %%
import importlib
import pandas as pd
import plausibility_formula_comparison as pfc
importlib.reload(pfc)

print("FORMULAS:", pfc.FORMULAS)
print("FORMULAS_DIST:", pfc.FORMULAS_DIST)
print("STRATEGIES:", pfc.STRATEGIES)
print("KGS:", pfc.KGS)
# Out:
# FORMULAS: ['base', 'gain', 'softmax', 'comb']
# FORMULAS_DIST: ['base_dist', 'gain_dist', 'softmax_dist', 'comb_dist']
# STRATEGIES: ['c-b-n-s', 'r-n-s']
# KGS: ['miRNA-KG', 'PKT-KG', 'Hetionet', 'PrimeKG', 'OptimusKG']

# %% [markdown]
# ## Run the bioKGs separately
#
# Pick one KG and run that cell to compute the results for evaluating the quality of the plausibility formulas.

# %%
KG = "miRNA-KG"
pfc.main(kgs=[KG])
# Out:
# === miRNA-KG ===
# Saved csv_results/miRNA-KG.csv (8 rows)

# %%
KG = "PKT-KG"
pfc.main(kgs=[KG])

# %%
KG = "Hetionet"
pfc.main(kgs=[KG])

# %%
KG = "PrimeKG"
pfc.main(kgs=[KG])

# %%
KG = "OptimusKG"
pfc.main(kgs=[KG])

# %%
# Displays selected KG that was run last above 
pd.read_csv(f"csv_results/{KG}.csv")
