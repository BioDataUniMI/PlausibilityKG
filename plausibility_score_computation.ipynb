# %%
from plausibility_score_computation import compute_plausibility_score, show_schema_facts

# %%
all_available_schemas = show_schema_facts()
# Out:
# === miRNA-KG ===
# Gene - causes or contributes to condition - Disease
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/1020
#   Disease id example: http://purl.obolibrary.org/obo/MONDO_1012483
# miRNA - in similarity relationship with - miRNA
#   miRNA id example: https://rnacentral.org/rna/URS000075998A_9606
#   miRNA id example: https://rnacentral.org/rna/URS0000B6B6B7_9606
# miRNA - causes or contributes to condition - Disease
#   miRNA id example: https://rnacentral.org/rna/URS000075CE58_9606
#   Disease id example: http://purl.obolibrary.org/obo/MONDO_0016968
# miRNA - under expressed in - Disease
#   miRNA id example: https://rnacentral.org/rna/URS000075C626_9606
#   Disease id example: http://purl.obolibrary.org/obo/MONDO_0015600
# miRNA - over expressed in - Disease
#   miRNA id example: https://rnacentral.org/rna/URS000075A993_9606
#   Disease id example: http://purl.obolibrary.org/obo/MONDO_1011283
# miRNA - is causal somatic mutation in - Disease
#   miRNA id example: https://rnacentral.org/rna/URS00002198F3_9606
#   Disease id example: http://purl.obolibrary.org/obo/MONDO_0009118
# Gene - genetically interacts with - Gene
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/100423042
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/728748
# miRNA - regulates activity of - Gene
#   miRNA id example: https://rnacentral.org/rna/URS000017EA6A_9606
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/102723981
# miRNA - participates in - GO
#   miRNA id example: https://rnacentral.org/rna/URS0000521832_9606
#   GO id example: http://purl.obolibrary.org/obo/GO_0046186
# miRNA - has function - GO
#   miRNA id example: https://rnacentral.org/rna/URS0000D4EFF8_9606
#   GO id example: http://purl.obolibrary.org/obo/GO_0099189
# miRNA - located in - GO
#   miRNA id example: https://rnacentral.org/rna/URS0000D53F1E_9606
#   GO id example: http://purl.obolibrary.org/obo/GO_0032537
# miRNA - part of - GO
#   miRNA id example: https://rnacentral.org/rna/URS000064A21C_9606
#   GO id example: http://purl.obolibrary.org/obo/GO_0070225
# === PKT-KG ===
# Protein - located in - Anatomy
#   Protein id example: http://purl.obolibrary.org/obo/PR_P27635
#   Anatomy id example: http://purl.obolibrary.org/obo/UBERON_0004937
# Protein - located in - Cell
#   Protein id example: http://purl.obolibrary.org/obo/PR_000082197
#   Cell id example: http://purl.obolibrary.org/obo/CLO_0021288
# Protein - molecularly interacts with - Protein
#   Protein id example: http://purl.obolibrary.org/obo/PR_Q8N8Z3
#   Protein id example: http://purl.obolibrary.org/obo/PR_Q29983-2
# GO - negatively regulates - GO
#   GO id example: http://purl.obolibrary.org/obo/GO_0070946
#   GO id example: http://purl.obolibrary.org/obo/GO_0003848
# GO - positively regulates - GO
#   GO id example: http://purl.obolibrary.org/obo/GO_0001818
#   GO id example: http://purl.obolibrary.org/obo/GO_1904516
# GO - regulates - GO
#   GO id example: http://purl.obolibrary.org/obo/GO_0009432
#   GO id example: http://purl.obolibrary.org/obo/GO_1903343
# Chemical - participates in - GO
#   Chemical id example: http://purl.obolibrary.org/obo/CHEBI_28506
#   GO id example: http://purl.obolibrary.org/obo/GO_0010968
# Chemical - molecularly interacts with - GO
#   Chemical id example: http://purl.obolibrary.org/obo/CHEBI_123419
#   GO id example: http://purl.obolibrary.org/obo/GO_0033970
# Protein - enables - GO
#   Protein id example: http://purl.obolibrary.org/obo/PR_000053062
#   GO id example: http://purl.obolibrary.org/obo/GO_0016243
# Protein - located in - GO
#   Protein id example: https://www.rna-society.org/cncrnadb?CNC_N_000217
#   GO id example: http://purl.obolibrary.org/obo/GO_0008720
# Chemical - interacts with - Gene
#   Chemical id example: http://purl.obolibrary.org/obo/CHEBI_109884
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/100271362
# Chemical - interacts with - Protein
#   Chemical id example: http://purl.obolibrary.org/obo/CHEBI_99289
#   Protein id example: http://purl.obolibrary.org/obo/PR_000070751
# Chemical - molecularly interacts with - Protein
#   Chemical id example: http://purl.obolibrary.org/obo/CHEBI_179920
#   Protein id example: http://purl.obolibrary.org/obo/PR_000080167
# Chemical - is substance that treats - Disease
#   Chemical id example: http://purl.obolibrary.org/obo/CHEBI_222419
#   Disease id example: http://purl.obolibrary.org/obo/MONDO_0060765
# Chemical - participates in - Pathway
#   Chemical id example: http://purl.obolibrary.org/obo/CHEBI_136988
#   Pathway id example: https://reactome.org/content/detail/R-HSA-429947
# Protein - participates in - Pathway
#   Protein id example: http://purl.obolibrary.org/obo/PR_000058286
#   Pathway id example: https://www.wikipathways.org/instance/WP4725
# Gene - causes or contributes to condition - Disease
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/124908504
#   Disease id example: http://purl.obolibrary.org/obo/MONDO_0004651
# Gene - genetically interacts with - Gene
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/100271119
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/7157
# Gene - interacts with - Protein
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/100873187
#   Protein id example: http://bigdata.ibp.ac.cn/SmProt/SmProt.php?ID=SPROHSA23905
# Gene - participates in - Pathway
#   Gene id example: http://www.ncbi.nlm.nih.gov/gene/124907125
#   Pathway id example: http://purl.obolibrary.org/obo/PW_0002237
# === Hetionet ===
# Anatomy - downregulates - Gene
#   Anatomy id example: Anatomy::UBERON:0001677
#   Gene id example: Gene::388799
# Anatomy - expresses - Gene
#   Anatomy id example: Anatomy::UBERON:0002097
#   Gene id example: Gene::285242
# Anatomy - upregulates - Gene
#   Anatomy id example: Anatomy::UBERON:0002397
#   Gene id example: Gene::3822
# Compound - binds - Gene
#   Compound id example: Compound::DB00963
#   Gene id example: Gene::92979
# Compound - downregulates - Gene
#   Compound id example: Compound::DB00275
#   Gene id example: Gene::83539
# Compound - upregulates - Gene
#   Compound id example: Compound::DB06213
#   Gene id example: Gene::699
# Compound - causes - Side_effect
#   Compound id example: Compound::DB01094
#   Side_effect id example: Side_effect::C0039685
# Compound - resembles - Compound
#   Compound id example: Compound::DB08990
#   Compound id example: Compound::DB01435
# Disease - associates - Gene
#   Disease id example: Disease::DOID:9008
#   Gene id example: Gene::283518
# Disease - downregulates - Gene
#   Disease id example: Disease::DOID:4481
#   Gene id example: Gene::5091
# Disease - upregulates - Gene
#   Disease id example: Disease::DOID:11920
#   Gene id example: Gene::338755
# Disease - localizes - Anatomy
#   Disease id example: Disease::DOID:0050741
#   Anatomy id example: Anatomy::UBERON:0002371
# Disease - presents - Symptom
#   Disease id example: Disease::DOID:1936
#   Symptom id example: Symptom::D051346
# Gene - covaries - Gene
#   Gene id example: Gene::479
#   Gene id example: Gene::378884
# Gene - interacts - Gene
#   Gene id example: Gene::254228
#   Gene id example: Gene::285423
# Gene - regulates - Gene
#   Gene id example: Gene::100289187
#   Gene id example: Gene::100996713
# Gene - participates - Biological_process
#   Gene id example: Gene::24148
#   Biological_process id example: Biological_process::GO:0031663
# Gene - participates - Cellular_component
#   Gene id example: Gene::100287979
#   Cellular_component id example: Cellular_component::GO:0005652
# Gene - participates - Molecular_function
#   Gene id example: Gene::101928675
#   Molecular_function id example: Molecular_function::GO:0004830
# Gene - participates - Pathway
#   Gene id example: Gene::64167
#   Pathway id example: Pathway::PC7_1233
# Pharmacologic_class - includes - Compound
#   Pharmacologic_class id example: Pharmacologic_class::N0000009909
#   Compound id example: Compound::DB00664
# === PrimeKG ===
# Anatomy - expression absent - Gene_and_or_protein
#   Anatomy id example: UBERON::3000663
#   Gene_and_or_protein id example: NCBI::79823
# Anatomy - expression present - Gene_and_or_protein
#   Anatomy id example: UBERON::4300235
#   Gene_and_or_protein id example: NCBI::390243
# Biological_process - interacts with - Exposure
#   Biological_process id example: GO::42850
#   Exposure id example: CTD::D005227
# Biological_process - interacts with - Gene_and_or_protein
#   Biological_process id example: GO::71466
#   Gene_and_or_protein id example: NCBI::22943
# Cellular_component - interacts with - Gene_and_or_protein
#   Cellular_component id example: GO::90734
#   Gene_and_or_protein id example: NCBI::28299
# Disease - associated with - Gene_and_or_protein
#   Disease id example: MONDO::12761
#   Gene_and_or_protein id example: NCBI::2215
# Disease - contraindication - Drug
#   Disease id example: MONDO::3103
#   Drug id example: DrugBank::DB03066
# Disease - indication - Drug
#   Disease id example: MONDO::19196
#   Drug id example: DrugBank::DB12212
# Disease - off label use - Drug
#   Disease id example: MONDO::5174
#   Drug id example: DrugBank::DB00469
# Disease - linked to - Exposure
#   Disease id example: MONDO::5734
#   Exposure id example: CTD::D003993
# Disease - phenotype absent - Effect_and_or_phenotype
#   Disease id example: MONDO::7122
#   Effect_and_or_phenotype id example: HPO::11801
# Disease - phenotype present - Effect_and_or_phenotype
#   Disease id example: MONDO_grouped::9656_9657_9655_9658
#   Effect_and_or_phenotype id example: HPO::11971
# Drug - enzyme - Gene_and_or_protein
#   Drug id example: DrugBank::DB06819
#   Gene_and_or_protein id example: NCBI::10769
# Drug - target - Gene_and_or_protein
#   Drug id example: DrugBank::DB01807
#   Gene_and_or_protein id example: NCBI::109617018
# Drug - transporter - Gene_and_or_protein
#   Drug id example: DrugBank::DB01551
#   Gene_and_or_protein id example: NCBI::149461
# Drug - side effect - Effect_and_or_phenotype
#   Drug id example: DrugBank::DB07854
#   Effect_and_or_phenotype id example: HPO::750
# Drug - synergistic interaction - Drug
#   Drug id example: DrugBank::DB15217
#   Drug id example: DrugBank::DB09381
# Effect_and_or_phenotype - associated with - Gene_and_or_protein
#   Effect_and_or_phenotype id example: HPO::12691
#   Gene_and_or_protein id example: NCBI::4674
# Exposure - interacts with - Gene_and_or_protein
#   Exposure id example: CTD::D000085
#   Gene_and_or_protein id example: NCBI::81492
# Gene_and_or_protein - interacts with - Molecular_function
#   Gene_and_or_protein id example: NCBI::440
#   Molecular_function id example: GO::102345
# Gene_and_or_protein - interacts with - Pathway
#   Gene_and_or_protein id example: NCBI::23569
#   Pathway id example: REACTOME::R-HSA-8853659
# Gene_and_or_protein - ppi - Gene_and_or_protein
#   Gene_and_or_protein id example: NCBI::1012
#   Gene_and_or_protein id example: NCBI::7130
# === OptimusKG ===
# Anatomy - EXPRESSION_ABSENT - Gene
#   Anatomy id example: UBERON_0003641
#   Gene id example: ENSG00000287384
# Anatomy - EXPRESSION_PRESENT - Gene
#   Anatomy id example: UBERON_0036168
#   Gene id example: ENSG00000215325
# Drug - ASSOCIATED_WITH - Phenotype
#   Drug id example: CHEMBL101740
#   Phenotype id example: HP_6001210
# Drug - CONTRAINDICATION - Phenotype
#   Drug id example: CHEMBL4596392
#   Phenotype id example: HP_0010203
# Drug - INDICATION - Phenotype
#   Drug id example: DRUGBANK:DB14843
#   Phenotype id example: HP_0040128
# Drug - OFF_LABEL_USE - Disease
#   Drug id example: CHEMBL6
#   Disease id example: MONDO_0010121
# Drug - CONTRAINDICATION - Disease
#   Drug id example: DRUGBANK:DB05892
#   Disease id example: MONDO_0001407
# Drug - INDICATION - Disease
#   Drug id example: CHEMBL3707252
#   Disease id example: MONDO_0003759
# Drug - TARGET - Gene
#   Drug id example: CHEMBL5095354
#   Gene id example: ENSG00000174307
# Drug - TRANSPORTER - Gene
#   Drug id example: CHEMBL1201594
#   Gene id example: ENSG00000272721
# Drug - ENZYME - Gene
#   Drug id example: CHEMBL1182210
#   Gene id example: ENSG00000200882
# Biological_process - INTERACTS_WITH - Gene
#   Biological_process id example: GO_0002831
#   Gene id example: ENSG00000235893
# Cellular_component - INTERACTS_WITH - Gene
#   Cellular_component id example: GO_0044354
#   Gene id example: ENSG00000237616
# Disease - ASSOCIATED_WITH - Gene
#   Disease id example: MONDO_0011504
#   Gene id example: ENSG00000248608
# Pathway - INTERACTS_WITH - Gene
#   Pathway id example: REACT:R-HSA-9865118
#   Gene id example: ENSG00000278551
# Disease - PHENOTYPE_PRESENT - Phenotype
#   Disease id example: MONDO_0011219
#   Phenotype id example: HP_0034199
# Drug - SYNERGISTIC_INTERACTION - Drug
#   Drug id example: CHEMBL4298208
#   Drug id example: CHEMBL2108462
# Exposure - INTERACTS_WITH - Biological_process
#   Exposure id example: MESH:D005663
#   Biological_process id example: GO_0031118
# Exposure - INTERACTS_WITH - Gene
#   Exposure id example: MESH:D004602
#   Gene id example: ENSG00000232613
# Exposure - LINKED_TO - Disease
#   Exposure id example: MESH:D008939
#   Disease id example: EFO_0801638
# Phenotype - ASSOCIATED_WITH - Gene
#   Phenotype id example: HP_3000050
#   Gene id example: ENSG00000128641
# Gene - INTERACTS_WITH - Gene
#   Gene id example: ENSG00000137267
#   Gene id example: ENSG00000168175
# Molecular_function - INTERACTS_WITH - Gene
#   Molecular_function id example: GO_0102481
#   Gene id example: ENSG00000279447

# %%
# Pick a schema fact from the KG schemas. See all available schema facts by calling `show_schema_facts()` 
# (miRNA_KG_relations, PKT_KG_relations, Hetionet_relations, PrimeKG_relations, OptimusKG_relations),
# then provide the source and target node IDs to score and specify its region.

# Example below is a real edge from miRNA-KG

schema_fact = 'miRNA - causes or contributes to condition - Disease'
source_id = 'https://rnacentral.org/rna/URS00000011DF_9606'
target_id = 'http://purl.obolibrary.org/obo/MONDO_0000452'

compute_plausibility_score(schema_fact, source_id, target_id)
# Out:
# Triple is in the Plausible region, Plausibility Score: 0.8936
# Implausible and Uncertain Region Threshold: 0.2337 | Uncertain and Plausible Region Threshold: 0.7203

# %%
# PKT-KG example
schema_fact = 'Chemical - is substance that treats - Disease'
source_id = 'http://purl.obolibrary.org/obo/CHEBI_100147'
target_id = 'http://purl.obolibrary.org/obo/MONDO_0000440'

compute_plausibility_score(schema_fact, source_id, target_id)
# Out:
# Triple is in the Plausible region, Plausibility Score: 0.9854
# Implausible and Uncertain Region Threshold: 0.2686 | Uncertain and Plausible Region Threshold: 0.9787

# %%
# Hetionet example
schema_fact = 'Compound - resembles - Compound'
source_id = 'Compound::DB01069'
target_id = 'Compound::DB00777'

compute_plausibility_score(schema_fact, source_id, target_id)

# %%
# PrimeKG example
schema_fact = 'Drug - target - Gene_and_or_protein'
source_id = 'DrugBank::DB00641'
target_id = 'NCBI::3156'

compute_plausibility_score(schema_fact, source_id, target_id)

# %%
# OptimusKG example
schema_fact = 'Drug - TARGET - Gene'
source_id = 'CHEMBL432162'
target_id = 'ENSG00000132603'

compute_plausibility_score(schema_fact, source_id, target_id)
